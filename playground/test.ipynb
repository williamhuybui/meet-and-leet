# %%
a = [(0,72), (1,73), (2,75)]
a[-1][0]
a[len(a)-1][0]
# Out:
# 2

# %%
a = [(0,72, [1,2]), (1,73, [[10,11],5]), (2,75, [6,8])]
a[1][2][0][1]
# Out:
# 11

# %%
a = [1,2,3,4,5]
for i in range(len(a)//2):
    a[i], a[-i-1] = a[-i-1], a[i]
a
# Out:
# [5, 4, 3, 2, 1]

# %%
a[::-1]
# Out:
# [1, 2, 3, 4, 5]
